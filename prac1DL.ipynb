# %%
from tensorflow import keras

# %%
from keras import datasets

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

# %%
print("Training data shape:", train_images.shape)
# Out:
# Training data shape: (60000, 28, 28)

# %%
print("Test data shape:", test_images.shape)
# Out:
# Test data shape: (10000, 28, 28)

# %%
pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in c:\users\91772\anaconda3\lib\site-packages (2.9.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: torchvision in c:\users\91772\anaconda3\lib\site-packages (0.24.1)
# Requirement already satisfied: torchaudio in c:\users\91772\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: filelock in c:\users\91772\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\91772\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\91772\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\91772\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\91772\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\91772\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\91772\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: numpy in c:\users\91772\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\91772\anaconda3\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\91772\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\91772\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)

# %%
import torch

# %%
import torch.nn as nn

# %%
print("PyTorch Version:", torch.__version__)
# Out:
# PyTorch Version: 2.9.1+cpu

# %%
x = torch.tensor([5.0], requires_grad=True)

# %%
y = torch.tensor([7.0], requires_grad=True)
z = x + y

# %%
print("PyTorch addition test: z =", z.item())
# Out:
# PyTorch addition test: z = 12.0

# %%
import tensorflow as tf

# %%
print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.20.0

# %%
hello = tf.constant("Hello TensorFlow!")
print(hello.numpy())
# Out:
# b'Hello TensorFlow!'
