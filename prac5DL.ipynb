# %%
# ---------------------------------------------------------
# EXPERIMENT 5 - Continuous Bag of Words (CBOW) with Keras
# ---------------------------------------------------------


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Lambda, Input
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import numpy as np
import re, os
from gensim.models import KeyedVectors

# Reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# %%
# Step 2: Small dataset (you can replace with your own sentences)

paragraph = (
    "It is a pleasant day. I love to walk in the park. "
    "The birds are singing and the breeze is cool. "
    "Children are playing games with joy. "
    "Learning new things every day feels rewarding."
)

print(paragraph)
# Out:
# It is a pleasant day. I love to walk in the park. The birds are singing and the breeze is cool. Children are playing games with joy. Learning new things every day feels rewarding.

# %%
# Step 3: Preprocess and tokenize

def simple_clean(text):
    text = text.lower()
    text = re.sub(r"[^a-zA-Z0-9\s\.]", "", text)  # keep letters, numbers, space, dot
    text = re.sub(r"\s+", " ", text).strip()
    return text

# Clean text
cleaned = simple_clean(paragraph)

# Split into sentences
sentences = [s.strip() for s in cleaned.split('.') if s.strip()]
print("Sentences:", sentences)

# Tokenize
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)

word_index = tokenizer.word_index
vocab_size = len(word_index) + 1  # +1 for padding
print("Vocabulary size:", vocab_size)
print("Word index:", word_index)

# Convert sentences to sequences of word IDs
seqs = tokenizer.texts_to_sequences(sentences)
print("Sequences:", seqs)
# Out:
# Sentences: ['it is a pleasant day', 'i love to walk in the park', 'the birds are singing and the breeze is cool', 'children are playing games with joy', 'learning new things every day feels rewarding']
# Vocabulary size: 31
# Word index: {'<OOV>': 1, 'the': 2, 'is': 3, 'day': 4, 'are': 5, 'it': 6, 'a': 7, 'pleasant': 8, 'i': 9, 'love': 10, 'to': 11, 'walk': 12, 'in': 13, 'park': 14, 'birds': 15, 'singing': 16, 'and': 17, 'breeze': 18, 'cool': 19, 'children': 20, 'playing': 21, 'games': 22, 'with': 23, 'joy': 24, 'learning': 25, 'new': 26, 'things': 27, 'every': 28, 'feels': 29, 'rewarding': 30}
# Sequences: [[6, 3, 7, 8, 4], [9, 10, 11, 12, 13, 2, 14], [2, 15, 5, 16, 17, 2, 18, 3, 19], [20, 5, 21, 22, 23, 24], [25, 26, 27, 28, 4, 29, 30]]

# %%
def cbow_training_pairs(seqs, window_size, vocab_size):
    contexts = []
    targets = []
    total_len = 2 * window_size  # left + right context
    
    for text in seqs:
        L = len(text)
        for idx, word in enumerate(text):
            if word == 0:
                continue
            
            start = max(0, idx - window_size)
            end = min(L, idx + window_size + 1)
            
            # Collect context words (exclude target word)
            context = [text[i] for i in range(start, end) if i != idx]
            
            # Pad context
            if len(context) < total_len:
                pad_left = (total_len - len(context)) // 2
                pad_right = total_len - len(context) - pad_left
                context = [0] * pad_left + context + [0] * pad_right
            else:
                context = context[:total_len]
            
            contexts.append(context)
            targets.append(word)
    
    X = np.array(contexts)
    y = to_categorical(np.array(targets), num_classes=vocab_size)
    return X, y

# %%
# Step 5: Build CBOW model
window_size = 2
embed_dim = 50
context_len = 2 * window_size

model = Sequential([
    Input(shape=(context_len,)),
    Embedding(input_dim=vocab_size, output_dim=embed_dim, name="embedding"),
    Lambda(lambda x: tf.reduce_mean(x, axis=1), name="context_mean"),
    Dense(vocab_size, activation="softmax")
])

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\91772\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 4, 50)          │         1,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ context_mean (Lambda)           │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 31)             │         1,581 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,131 (12.23 KB)
#  Trainable params: 3,131 (12.23 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
window_size = 2
X, y = cbow_training_pairs(seqs, window_size, vocab_size)
print("X shape:", X.shape, "y shape:", y.shape)
# Out:
# X shape: (34, 4) y shape: (34, 31)

# %%
history = model.fit(X, y, epochs=200, batch_size=32, verbose=1)
# Out:
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.0294 - loss: 3.4357
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.0882 - loss: 3.4293
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1176 - loss: 3.4243
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.1176 - loss: 3.4194
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1176 - loss: 3.4145
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.1176 - loss: 3.4097
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.1471 - loss: 3.4049
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1765 - loss: 3.4001
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.1765 - loss: 3.3952
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.2059 - loss: 3.3903
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2059 - loss: 3.3854
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.2059 - loss: 3.3805
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.2647 - loss: 3.3754
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.2647 - loss: 3.3703
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.2941 - loss: 3.3652
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.2941 - loss: 3.3599
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.2941 - loss: 3.3546
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2941 - loss: 3.3492
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2941 - loss: 3.3437
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.2941 - loss: 3.3381
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2941 - loss: 3.3323
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2353 - loss: 3.3265
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.2353 - loss: 3.3205
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.2353 - loss: 3.3145
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2353 - loss: 3.3083
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2353 - loss: 3.3020
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2353 - loss: 3.2955
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2647 - loss: 3.2890
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2647 - loss: 3.2822
# Epoch 30/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2647 - loss: 3.2754
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.2941 - loss: 3.2684
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.2941 - loss: 3.2613
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.2941 - loss: 3.2541
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.2941 - loss: 3.2467
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.2941 - loss: 3.2392
# Epoch 36/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2941 - loss: 3.2315
# Epoch 37/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.2941 - loss: 3.2237
# Epoch 38/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2941 - loss: 3.2158
# Epoch 39/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2941 - loss: 3.2077
# Epoch 40/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.2941 - loss: 3.1995
# Epoch 41/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2941 - loss: 3.1911
# Epoch 42/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2941 - loss: 3.1827
# Epoch 43/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.2941 - loss: 3.1740
# Epoch 44/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2941 - loss: 3.1653
# Epoch 45/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.2941 - loss: 3.1564
# Epoch 46/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2941 - loss: 3.1474
# Epoch 47/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2941 - loss: 3.1382
# Epoch 48/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.2941 - loss: 3.1289
# Epoch 49/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2941 - loss: 3.1195
# Epoch 50/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2941 - loss: 3.1100
# Epoch 51/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2941 - loss: 3.1003
# Epoch 52/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2941 - loss: 3.0905
# Epoch 53/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3235 - loss: 3.0806
# Epoch 54/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3235 - loss: 3.0706
# Epoch 55/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3235 - loss: 3.0605
# Epoch 56/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3529 - loss: 3.0503
# Epoch 57/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3529 - loss: 3.0399
# Epoch 58/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3529 - loss: 3.0295
# Epoch 59/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3529 - loss: 3.0189
# Epoch 60/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3529 - loss: 3.0083
# Epoch 61/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3529 - loss: 2.9975
# Epoch 62/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3529 - loss: 2.9867
# Epoch 63/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3824 - loss: 2.9758
# Epoch 64/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.3824 - loss: 2.9648
# Epoch 65/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3824 - loss: 2.9537
# Epoch 66/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4118 - loss: 2.9425
# Epoch 67/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4118 - loss: 2.9313
# Epoch 68/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4118 - loss: 2.9200
# Epoch 69/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4118 - loss: 2.9086
# Epoch 70/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4118 - loss: 2.8972
# Epoch 71/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4118 - loss: 2.8857
# Epoch 72/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4118 - loss: 2.8741
# Epoch 73/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4118 - loss: 2.8625
# Epoch 74/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4118 - loss: 2.8508
# Epoch 75/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4118 - loss: 2.8391
# Epoch 76/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4118 - loss: 2.8274
# Epoch 77/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4118 - loss: 2.8156
# Epoch 78/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4118 - loss: 2.8037
# Epoch 79/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4118 - loss: 2.7918
# Epoch 80/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4118 - loss: 2.7799
# Epoch 81/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4118 - loss: 2.7679
# Epoch 82/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.4118 - loss: 2.7559
# Epoch 83/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4118 - loss: 2.7439
# Epoch 84/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4118 - loss: 2.7318
# Epoch 85/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4118 - loss: 2.7197
# Epoch 86/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4118 - loss: 2.7076
# Epoch 87/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.4118 - loss: 2.6954
# Epoch 88/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4118 - loss: 2.6833
# Epoch 89/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4118 - loss: 2.6710
# Epoch 90/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.4118 - loss: 2.6588
# Epoch 91/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4118 - loss: 2.6465
# Epoch 92/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4118 - loss: 2.6342
# Epoch 93/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4118 - loss: 2.6218
# Epoch 94/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4118 - loss: 2.6094
# Epoch 95/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4118 - loss: 2.5970
# Epoch 96/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4118 - loss: 2.5846
# Epoch 97/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4118 - loss: 2.5721
# Epoch 98/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4118 - loss: 2.5596
# Epoch 99/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4118 - loss: 2.5470
# Epoch 100/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4118 - loss: 2.5344
# Epoch 101/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4118 - loss: 2.5217
# Epoch 102/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4118 - loss: 2.5090
# Epoch 103/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.4118 - loss: 2.4963
# Epoch 104/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4412 - loss: 2.4835
# Epoch 105/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4412 - loss: 2.4707
# Epoch 106/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.4412 - loss: 2.4578
# Epoch 107/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.4412 - loss: 2.4449
# Epoch 108/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4412 - loss: 2.4320
# Epoch 109/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4412 - loss: 2.4190
# Epoch 110/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4412 - loss: 2.4059
# Epoch 111/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.4412 - loss: 2.3928
# Epoch 112/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4412 - loss: 2.3797
# Epoch 113/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.4412 - loss: 2.3665
# Epoch 114/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4412 - loss: 2.3533
# Epoch 115/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4412 - loss: 2.3401
# Epoch 116/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4412 - loss: 2.3268
# Epoch 117/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4706 - loss: 2.3135
# Epoch 118/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4706 - loss: 2.3001
# Epoch 119/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4706 - loss: 2.2867
# Epoch 120/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4706 - loss: 2.2733
# Epoch 121/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4706 - loss: 2.2598
# Epoch 122/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4706 - loss: 2.2464
# Epoch 123/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4706 - loss: 2.2329
# Epoch 124/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5000 - loss: 2.2193
# Epoch 125/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5000 - loss: 2.2058
# Epoch 126/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5000 - loss: 2.1922
# Epoch 127/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5000 - loss: 2.1787
# Epoch 128/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5000 - loss: 2.1651
# Epoch 129/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5000 - loss: 2.1515
# Epoch 130/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5000 - loss: 2.1379
# Epoch 131/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5000 - loss: 2.1243
# Epoch 132/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5000 - loss: 2.1107
# Epoch 133/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5294 - loss: 2.0971
# Epoch 134/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5294 - loss: 2.0836
# Epoch 135/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5294 - loss: 2.0700
# Epoch 136/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5294 - loss: 2.0564
# Epoch 137/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5294 - loss: 2.0429
# Epoch 138/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5294 - loss: 2.0294
# Epoch 139/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5294 - loss: 2.0159
# Epoch 140/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5294 - loss: 2.0024
# Epoch 141/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5294 - loss: 1.9889
# Epoch 142/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5294 - loss: 1.9755
# Epoch 143/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5294 - loss: 1.9621
# Epoch 144/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5294 - loss: 1.9487
# Epoch 145/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5294 - loss: 1.9354
# Epoch 146/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5294 - loss: 1.9221
# Epoch 147/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5294 - loss: 1.9089
# Epoch 148/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5294 - loss: 1.8957
# Epoch 149/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5294 - loss: 1.8825
# Epoch 150/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5294 - loss: 1.8694
# Epoch 151/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5294 - loss: 1.8563
# Epoch 152/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5294 - loss: 1.8433
# Epoch 153/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5294 - loss: 1.8303
# Epoch 154/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5294 - loss: 1.8174
# Epoch 155/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5294 - loss: 1.8046
# Epoch 156/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5588 - loss: 1.7918
# Epoch 157/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5882 - loss: 1.7790
# Epoch 158/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5882 - loss: 1.7663
# Epoch 159/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5882 - loss: 1.7537
# Epoch 160/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5882 - loss: 1.7412
# Epoch 161/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5882 - loss: 1.7287
# Epoch 162/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5882 - loss: 1.7162
# Epoch 163/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5882 - loss: 1.7038
# Epoch 164/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5882 - loss: 1.6915
# Epoch 165/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5882 - loss: 1.6793
# Epoch 166/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5882 - loss: 1.6671
# Epoch 167/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5882 - loss: 1.6550
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5882 - loss: 1.6430
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5882 - loss: 1.6310
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5882 - loss: 1.6191
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5882 - loss: 1.6073
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5882 - loss: 1.5956
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5882 - loss: 1.5839
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5882 - loss: 1.5723
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5882 - loss: 1.5607
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.6176 - loss: 1.5493
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6176 - loss: 1.5379
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6176 - loss: 1.5266
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6176 - loss: 1.5153
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6176 - loss: 1.5041
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6176 - loss: 1.4930
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6176 - loss: 1.4820
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6176 - loss: 1.4711
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6176 - loss: 1.4602
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6176 - loss: 1.4494
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6471 - loss: 1.4387
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7059 - loss: 1.4280
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7059 - loss: 1.4174
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7059 - loss: 1.4069
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7059 - loss: 1.3965
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7059 - loss: 1.3862
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7059 - loss: 1.3759
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7353 - loss: 1.3657
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7353 - loss: 1.3555
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7647 - loss: 1.3455
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7647 - loss: 1.3355
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7647 - loss: 1.3256
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7941 - loss: 1.3157
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7941 - loss: 1.3059
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7941 - loss: 1.2962

# %%
# Step 7: Save word vectors

weights = model.get_layer("embedding").get_weights()[0]

items = sorted([(w, idx) for w, idx in word_index.items() if idx < weights.shape[0] and idx != 0], key=lambda t: t[1])
num_vectors = len(items)

with open("vectors.txt", "w", encoding="utf-8") as f:
    f.write(f"{num_vectors} {embed_dim}\n")
    for word, idx in items:
        vec = " ".join(map(str, weights[idx].tolist()))
        f.write(f"{word} {vec}\n")

print("vectors.txt saved successfully!")
# Out:
# vectors.txt saved successfully!

# %%
# Step 8: Test with Gensim

cbow_vectors = KeyedVectors.load_word2vec_format("vectors.txt", binary=False)
print("Words in vocab:", cbow_vectors.index_to_key)

for w in ["day", "park", "children", "learning"]:
    if w in cbow_vectors:
        print(f"\nMost similar to '{w}':")
        print(cbow_vectors.most_similar(positive=[w], topn=5))
# Out:
# Words in vocab: ['<OOV>', 'the', 'is', 'day', 'are', 'it', 'a', 'pleasant', 'i', 'love', 'to', 'walk', 'in', 'park', 'birds', 'singing', 'and', 'breeze', 'cool', 'children', 'playing', 'games', 'with', 'joy', 'learning', 'new', 'things', 'every', 'feels', 'rewarding']
#
# Most similar to 'day':
# [('feels', 0.9427475333213806), ('new', 0.9356144666671753), ('things', 0.8961781859397888), ('love', 0.04066450148820877), ('learning', 0.028660761192440987)]
#
# Most similar to 'park':
# [('walk', 0.7422353625297546), ('birds', 0.514449417591095), ('in', 0.42957285046577454), ('and', 0.4218091368675232), ('to', 0.38650864362716675)]
#
# Most similar to 'children':
# [('games', 0.7136662006378174), ('birds', 0.6096868515014648), ('and', 0.574961245059967), ('singing', 0.42470690608024597), ('are', 0.3531719744205475)]
#
# Most similar to 'learning':
# [('every', 0.714691698551178), ('i', 0.2033466398715973), ('with', 0.15126410126686096), ('to', 0.1130979135632515), ('love', 0.11085328459739685)]
